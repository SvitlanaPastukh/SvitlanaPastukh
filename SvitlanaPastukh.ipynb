# %% [markdown]
# <a href="https://colab.research.google.com/github/SvitlanaPastukh/SvitlanaPastukh/blob/master/SvitlanaPastukh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from sklearn.utils import shuffle
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import numpy as np
import os
import matplotlib.pyplot as plot
from sklearn.metrics import confusion_matrix as CM

# !ls drive/My\ Drive/image_classification
# !cd drive/My\ Drive/image_classification/clas_train/clas_train; pwd


def get_classlabel(class_code):
               labels = {2:'glacier', 4:'sea', 0:'buildings', 1:'forest', 5:'street', 3:'mountain'}
               return labels[class_code]


def get_images(directory):
    Images = []
    Labels = []   # 0 for Building , 1 for forest, 2 for glacier, 3 for mountain, 4 for Sea , 5 for Street
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        print(labels)
        if labels == 'glacier': 
            label = 2
        elif labels == 'sea':
            label = 4
        elif labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label = 1
        elif labels == 'street':
            label = 5
        elif labels == 'mountain':
            label = 3
        i=0
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(128,128)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
            i=i+1
           
            if i==100:
              break
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepare


Images, Labels = get_images('drive/My Drive/image_classification/clas_train/clas_train/')
Images = np.array(Images) 
Labels = np.array(Labels)


print("Shape of Images:",Images.shape)
print("Shape of Labels:",Labels.shape)

f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images)-1)
        #print(i,j)
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')
# Out:
# clas_pred  clas_test  clas_train
# /content/drive/My Drive/image_classification/clas_train/clas_train
# forest
# buildings
# mountain
# glacier
# street
# sea
# Shape of Images: (600, 128, 128, 3)
# Shape of Labels: (600,)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('drive/My Drive/image_classification/clas_train/clas_train/',
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 14034 images belonging to 6 classes.

# %%
test_set = test_datagen.flow_from_directory('drive/My Drive/image_classification/clas_test/', 
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 3000 images belonging to 6 classes.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(128, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(128, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(128, activation = 'relu'))
classifier.add(Dense(6, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 126, 126, 128)     3584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 63, 63, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 61, 61, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               14745728
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 14,897,670
# Trainable params: 14,897,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
trained = classifier.fit(training_set,
                         steps_per_epoch = 140//32,
                         epochs = 40,  #15
                         validation_data = test_set,
                         validation_steps = 150//32)
# Out:
# Epoch 1/40
# 3/4 [=====================>........] - ETA: 9s - loss: 8.1684 - acc: 0.1771 Epoch 1/40
# 4/4 [==============================] - 30s 7s/step - loss: 2.0341 - acc: 0.1562
# 4/4 [==============================] - 67s 17s/step - loss: 7.2203 - acc: 0.1562 - val_loss: 2.0341 - val_acc: 0.1562
# Epoch 2/40
# 3/4 [=====================>........] - ETA: 0s - loss: 1.9737 - acc: 0.0938Epoch 1/40
# 4/4 [==============================] - 0s 70ms/step - loss: 1.7836 - acc: 0.1562
# 4/4 [==============================] - 5s 1s/step - loss: 1.9284 - acc: 0.1016 - val_loss: 1.7836 - val_acc: 0.1562
# Epoch 3/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.7827 - acc: 0.2083 Epoch 1/40
# 4/4 [==============================] - 0s 63ms/step - loss: 1.7707 - acc: 0.1641
# 4/4 [==============================] - 37s 9s/step - loss: 1.7744 - acc: 0.2422 - val_loss: 1.7707 - val_acc: 0.1641
# Epoch 4/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.7845 - acc: 0.1250 Epoch 1/40
# 4/4 [==============================] - 0s 59ms/step - loss: 1.6618 - acc: 0.2812
# 4/4 [==============================] - 36s 9s/step - loss: 1.7453 - acc: 0.1797 - val_loss: 1.6618 - val_acc: 0.2812
# Epoch 5/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.6072 - acc: 0.3646 Epoch 1/40
# 4/4 [==============================] - 0s 65ms/step - loss: 1.4941 - acc: 0.3438
# 4/4 [==============================] - 35s 9s/step - loss: 1.5821 - acc: 0.3672 - val_loss: 1.4941 - val_acc: 0.3438
# Epoch 6/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.5620 - acc: 0.3646 Epoch 1/40
# 4/4 [==============================] - 0s 71ms/step - loss: 1.3868 - acc: 0.4141
# 4/4 [==============================] - 36s 9s/step - loss: 1.4789 - acc: 0.4219 - val_loss: 1.3868 - val_acc: 0.4141
# Epoch 7/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.4273 - acc: 0.3854 Epoch 1/40
# 4/4 [==============================] - 0s 64ms/step - loss: 1.4830 - acc: 0.3984
# 4/4 [==============================] - 36s 9s/step - loss: 1.4409 - acc: 0.4062 - val_loss: 1.4830 - val_acc: 0.3984
# Epoch 8/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1825 - acc: 0.5625 Epoch 1/40
# 4/4 [==============================] - 0s 69ms/step - loss: 1.3634 - acc: 0.5234
# 4/4 [==============================] - 36s 9s/step - loss: 1.1853 - acc: 0.5625 - val_loss: 1.3634 - val_acc: 0.5234
# Epoch 9/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.0917 - acc: 0.5625 Epoch 1/40
# 4/4 [==============================] - 0s 76ms/step - loss: 1.6625 - acc: 0.3984
# 4/4 [==============================] - 35s 9s/step - loss: 1.1396 - acc: 0.5781 - val_loss: 1.6625 - val_acc: 0.3984
# Epoch 10/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1371 - acc: 0.5729 Epoch 1/40
# 4/4 [==============================] - 0s 69ms/step - loss: 1.4308 - acc: 0.4766
# 4/4 [==============================] - 40s 10s/step - loss: 1.2662 - acc: 0.5469 - val_loss: 1.4308 - val_acc: 0.4766
# Epoch 11/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1870 - acc: 0.4479 Epoch 1/40
# 4/4 [==============================] - 0s 66ms/step - loss: 1.6380 - acc: 0.4297
# 4/4 [==============================] - 36s 9s/step - loss: 1.1858 - acc: 0.4609 - val_loss: 1.6380 - val_acc: 0.4297
# Epoch 12/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.3303 - acc: 0.4688 Epoch 1/40
# 4/4 [==============================] - 0s 73ms/step - loss: 1.3585 - acc: 0.4922
# 4/4 [==============================] - 38s 9s/step - loss: 1.4073 - acc: 0.4375 - val_loss: 1.3585 - val_acc: 0.4922
# Epoch 13/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.2194 - acc: 0.5729 Epoch 1/40
# 4/4 [==============================] - 0s 71ms/step - loss: 1.5896 - acc: 0.4297
# 4/4 [==============================] - 40s 10s/step - loss: 1.2955 - acc: 0.5312 - val_loss: 1.5896 - val_acc: 0.4297
# Epoch 14/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1044 - acc: 0.5938 Epoch 1/40
# 4/4 [==============================] - 0s 69ms/step - loss: 1.2631 - acc: 0.5234
# 4/4 [==============================] - 39s 10s/step - loss: 1.1119 - acc: 0.5781 - val_loss: 1.2631 - val_acc: 0.5234
# Epoch 15/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.5327 - acc: 0.4375 Epoch 1/40
# 4/4 [==============================] - 0s 69ms/step - loss: 1.3965 - acc: 0.4219
# 4/4 [==============================] - 37s 9s/step - loss: 1.4538 - acc: 0.4453 - val_loss: 1.3965 - val_acc: 0.4219
# Epoch 16/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1326 - acc: 0.6042 Epoch 1/40
# 4/4 [==============================] - 0s 67ms/step - loss: 1.3756 - acc: 0.4688
# 4/4 [==============================] - 38s 10s/step - loss: 1.1905 - acc: 0.5703 - val_loss: 1.3756 - val_acc: 0.4688
# Epoch 17/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.0202 - acc: 0.6250 Epoch 1/40
# 4/4 [==============================] - 0s 63ms/step - loss: 1.3307 - acc: 0.5078
# 4/4 [==============================] - 34s 9s/step - loss: 1.0708 - acc: 0.5781 - val_loss: 1.3307 - val_acc: 0.5078
# Epoch 18/40
# 3/4 [=====================>........] - ETA: 8s - loss: 0.9996 - acc: 0.5938 Epoch 1/40
# 4/4 [==============================] - 0s 70ms/step - loss: 2.0039 - acc: 0.4219
# 4/4 [==============================] - 36s 9s/step - loss: 0.9760 - acc: 0.6250 - val_loss: 2.0039 - val_acc: 0.4219
# Epoch 19/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.1528 - acc: 0.5833 Epoch 1/40
# 4/4 [==============================] - 0s 65ms/step - loss: 1.3510 - acc: 0.5469
# 4/4 [==============================] - 37s 9s/step - loss: 1.1842 - acc: 0.5781 - val_loss: 1.3510 - val_acc: 0.5469
# Epoch 20/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0884 - acc: 0.5521 Epoch 1/40
# 4/4 [==============================] - 0s 69ms/step - loss: 2.0642 - acc: 0.4297
# 4/4 [==============================] - 37s 9s/step - loss: 1.0220 - acc: 0.5781 - val_loss: 2.0642 - val_acc: 0.4297
# Epoch 21/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.3825 - acc: 0.5104 Epoch 1/40
# 4/4 [==============================] - 0s 73ms/step - loss: 1.3050 - acc: 0.4922
# 4/4 [==============================] - 36s 9s/step - loss: 1.2869 - acc: 0.5234 - val_loss: 1.3050 - val_acc: 0.4922
# Epoch 22/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.1859 - acc: 0.5521 Epoch 1/40
# 4/4 [==============================] - 0s 61ms/step - loss: 1.5294 - acc: 0.4297
# 4/4 [==============================] - 35s 9s/step - loss: 1.1575 - acc: 0.5703 - val_loss: 1.5294 - val_acc: 0.4297
# Epoch 23/40
# 3/4 [=====================>........] - ETA: 10s - loss: 1.1751 - acc: 0.5104Epoch 1/40
# 4/4 [==============================] - 0s 70ms/step - loss: 1.2207 - acc: 0.5156
# 4/4 [==============================] - 46s 12s/step - loss: 1.1636 - acc: 0.5234 - val_loss: 1.2207 - val_acc: 0.5156
# Epoch 24/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.4246 - acc: 0.5000 Epoch 1/40
# 4/4 [==============================] - 0s 65ms/step - loss: 1.2179 - acc: 0.4922
# 4/4 [==============================] - 39s 10s/step - loss: 1.4005 - acc: 0.4844 - val_loss: 1.2179 - val_acc: 0.4922
# Epoch 25/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.1838 - acc: 0.5833 Epoch 1/40
# 4/4 [==============================] - 0s 67ms/step - loss: 1.6691 - acc: 0.3750
# 4/4 [==============================] - 38s 9s/step - loss: 1.1992 - acc: 0.5625 - val_loss: 1.6691 - val_acc: 0.3750
# Epoch 26/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0955 - acc: 0.6146 Epoch 1/40
# 4/4 [==============================] - 0s 62ms/step - loss: 1.1936 - acc: 0.5391
# 4/4 [==============================] - 39s 10s/step - loss: 1.0857 - acc: 0.6172 - val_loss: 1.1936 - val_acc: 0.5391
# Epoch 27/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1228 - acc: 0.5521 Epoch 1/40
# 4/4 [==============================] - 0s 74ms/step - loss: 1.2005 - acc: 0.5391
# 4/4 [==============================] - 38s 9s/step - loss: 1.1252 - acc: 0.5391 - val_loss: 1.2005 - val_acc: 0.5391
# Epoch 28/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0551 - acc: 0.5938 Epoch 1/40
# 4/4 [==============================] - 0s 71ms/step - loss: 1.6472 - acc: 0.4609
# 4/4 [==============================] - 35s 9s/step - loss: 1.0872 - acc: 0.5625 - val_loss: 1.6472 - val_acc: 0.4609
# Epoch 29/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.2080 - acc: 0.5104 Epoch 1/40
# 4/4 [==============================] - 0s 63ms/step - loss: 1.2629 - acc: 0.5469
# 4/4 [==============================] - 35s 9s/step - loss: 1.1719 - acc: 0.5391 - val_loss: 1.2629 - val_acc: 0.5469
# Epoch 30/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0011 - acc: 0.6146 Epoch 1/40
# 4/4 [==============================] - 0s 62ms/step - loss: 1.1398 - acc: 0.5547
# 4/4 [==============================] - 40s 10s/step - loss: 1.0103 - acc: 0.6094 - val_loss: 1.1398 - val_acc: 0.5547
# Epoch 31/40
# 3/4 [=====================>........] - ETA: 8s - loss: 0.9609 - acc: 0.6146 Epoch 1/40
# 4/4 [==============================] - 0s 74ms/step - loss: 1.5732 - acc: 0.4531
# 4/4 [==============================] - 33s 8s/step - loss: 1.0781 - acc: 0.5781 - val_loss: 1.5732 - val_acc: 0.4531
# Epoch 32/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.0157 - acc: 0.5521 Epoch 1/40
# 4/4 [==============================] - 0s 65ms/step - loss: 1.1647 - acc: 0.5547
# 4/4 [==============================] - 35s 9s/step - loss: 1.0582 - acc: 0.5469 - val_loss: 1.1647 - val_acc: 0.5547
# Epoch 33/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.1247 - acc: 0.5417 Epoch 1/40
# 4/4 [==============================] - 0s 72ms/step - loss: 1.2732 - acc: 0.5234
# 4/4 [==============================] - 37s 9s/step - loss: 1.0464 - acc: 0.5703 - val_loss: 1.2732 - val_acc: 0.5234
# Epoch 34/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0039 - acc: 0.6042 Epoch 1/40
# 4/4 [==============================] - 0s 65ms/step - loss: 1.2491 - acc: 0.5156
# 4/4 [==============================] - 37s 9s/step - loss: 1.0563 - acc: 0.5859 - val_loss: 1.2491 - val_acc: 0.5156
# Epoch 35/40
# 3/4 [=====================>........] - ETA: 9s - loss: 0.9075 - acc: 0.6250 Epoch 1/40
# 4/4 [==============================] - 0s 67ms/step - loss: 1.2878 - acc: 0.5312
# 4/4 [==============================] - 38s 9s/step - loss: 0.9413 - acc: 0.6016 - val_loss: 1.2878 - val_acc: 0.5312
# Epoch 36/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.1656 - acc: 0.5938 Epoch 1/40
# 4/4 [==============================] - 0s 66ms/step - loss: 1.1783 - acc: 0.5703
# 4/4 [==============================] - 37s 9s/step - loss: 1.2175 - acc: 0.5859 - val_loss: 1.1783 - val_acc: 0.5703
# Epoch 37/40
# 3/4 [=====================>........] - ETA: 9s - loss: 0.8727 - acc: 0.6771 Epoch 1/40
# 4/4 [==============================] - 0s 83ms/step - loss: 1.1322 - acc: 0.5391
# 4/4 [==============================] - 35s 9s/step - loss: 0.9335 - acc: 0.6250 - val_loss: 1.1322 - val_acc: 0.5391
# Epoch 38/40
# 3/4 [=====================>........] - ETA: 8s - loss: 1.1620 - acc: 0.5729 Epoch 1/40
# 4/4 [==============================] - 0s 72ms/step - loss: 1.2651 - acc: 0.5156
# 4/4 [==============================] - 35s 9s/step - loss: 1.1244 - acc: 0.5547 - val_loss: 1.2651 - val_acc: 0.5156
# Epoch 39/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0127 - acc: 0.6458 Epoch 1/40
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0605 - acc: 0.5938
# 4/4 [==============================] - 40s 10s/step - loss: 1.0482 - acc: 0.6250 - val_loss: 1.0605 - val_acc: 0.5938
# Epoch 40/40
# 3/4 [=====================>........] - ETA: 9s - loss: 1.0641 - acc: 0.5312 Epoch 1/40
# 4/4 [==============================] - 0s 75ms/step - loss: 1.0286 - acc: 0.5781
# 4/4 [==============================] - 38s 10s/step - loss: 1.0585 - acc: 0.5391 - val_loss: 1.0286 - val_acc: 0.5781

# %%
plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %%
plot.plot(trained.history['acc'])
plot.plot(trained.history['val_acc'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %%
pred_images, true_labels = get_images('drive/My Drive/image_classification/clas_test/')
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# mountain
# buildings
# forest
# sea
# street
# glacier
# (600, 128, 128, 3)

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(25):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(pred_images))
    pred_image = np.array([pred_images[rnd_number]])
    pred_class = get_classlabel(classifier.predict_classes(pred_image)[0])
    pred_prob = classifier.predict(pred_image).reshape(6)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            ax.set_title(pred_class+" "+get_classlabel(true_labels[rnd_number]))
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
        else:
            ax = plot.Subplot(fig, inner[j])
            ax.bar([0,1,2,3,4,5],pred_prob)
            fig.add_subplot(ax)


fig.show()

# %%
# Confusion matrix result

y_test = np.array(true_labels)


from sklearn.metrics import classification_report, confusion_matrix
y_pred = classifier.predict_classes(pred_images, verbose=2)


#confusion matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# 600/600 - 1s
# [[46  0 27  1 16 10]
#  [16 48  9  0  1 26]
#  [ 2  0 22  6 69  1]
#  [ 2  0  5 22 71  0]
#  [ 5  1 17  7 69  1]
#  [17  0 26  0  7 50]]
